# %%
import requests
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
deepgram = os.getenv('DEEPGRAM')

# %%
with open('meeting-audio.pcm', 'rb') as audio:
    url = "https://api.deepgram.com/v1/listen"
    headers = {
        'Authorization': f'Token {deepgram}',
        'Content-Type': 'audio/raw'  # Use 'audio/raw' for raw PCM audio files
    }
    params = {
        "encoding": "linear16",  # 16-bit signed PCM
        "channels": 1,  # Mono audio
        "sample_rate": 32000,  # Sample rate in Hz,
        "paragraphs": "true",
        "diarize": "true"
    }
    
    try:
        # Make the POST request to Deepgram API
        response = requests.post(url, headers=headers, params=params, data=audio)
        
        # Print the status and raise any errors
        print(f"Status Code: {response.status_code}")
        response.raise_for_status()  # Raise an error for bad responses
        
        # Parse the response JSON
        transcript = response.json()
        
        print("Transcript Data:", transcript_data)
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err} - {response.text}")
    except Exception as err:
        print(f"An error occurred while getting transcript from Deepgram: {err}")
# Out:
# Status Code: 200
# Transcript Data: {'metadata': {'transaction_key': 'deprecated', 'request_id': '574c48ae-21a6-420a-ba08-f15eafa42c4f', 'sha256': 'a689ffaf45498ee3df5d029ddf7ea6fe52d3322f8706bda3927357bca8202253', 'created': '2025-01-06T02:45:51.212Z', 'duration': 52.2, 'channels': 1, 'models': ['1ed36bac-f71c-4f3f-a31f-02fd6525c489'], 'model_info': {'1ed36bac-f71c-4f3f-a31f-02fd6525c489': {'name': 'general', 'version': '2024-01-26.8851', 'arch': 'base'}}}, 'results': {'channels': [{'alternatives': [{'transcript': "Y. Sag, Har, this is just to test to see if the bot is working. And I hope it is, it's recording some audio. I don't know. It's gonna work the way I want to work. But fuck man. Sometimes you just can't do anything. But I wanna make sure the audio filed is, yeah. Is good. Right. But you know, it should get the meeting soon.", 'confidence': 0.9404297, 'words': [{'word': 'y', 'start': 2.8265674, 'end': 3.0654323, 'confidence': 0.32958984, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'Y.'}, {'word': 'sag', 'start': 3.543162, 'end': 3.782027, 'confidence': 0.47973633, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'Sag,'}, {'word': 'har', 'start': 4.0208917, 'end': 4.2597566, 'confidence': 0.43945312, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'Har,'}, {'word': 'this', 'start': 4.817108, 'end': 4.8967295, 'confidence': 0.9873047, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'this'}, {'word': 'is', 'start': 4.8967295, 'end': 5.055973, 'confidence': 0.97558594, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'is'}, {'word': 'just', 'start': 5.055973, 'end': 5.215216, 'confidence': 0.9770508, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'just'}, {'word': 'to', 'start': 5.215216, 'end': 5.454081, 'confidence': 0.50683594, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'to'}, {'word': 'test', 'start': 5.454081, 'end': 5.613324, 'confidence': 0.94433594, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'test'}, {'word': 'to', 'start': 5.613324, 'end': 5.692946, 'confidence': 0.9746094, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'to'}, {'word': 'see', 'start': 5.692946, 'end': 5.852189, 'confidence': 0.9848633, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'see'}, {'word': 'if', 'start': 5.852189, 'end': 6.011432, 'confidence': 0.9765625, 'speaker': 0, 'speaker_confidence': 0.5785767, 'punctuated_word': 'if'}, {'word': 'the', 'start': 6.011432, 'end': 6.091054, 'confidence': 0.94140625, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'the'}, {'word': 'bot', 'start': 6.091054, 'end': 6.250297, 'confidence': 0.35839844, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'bot'}, {'word': 'is', 'start': 6.250297, 'end': 6.4095407, 'confidence': 0.8959961, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'is'}, {'word': 'working', 'start': 6.4095407, 'end': 6.8076487, 'confidence': 0.9980469, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'working.'}, {'word': 'and', 'start': 7.4446216, 'end': 7.5242434, 'confidence': 0.99316406, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'And'}, {'word': 'i', 'start': 7.6834865, 'end': 7.8427296, 'confidence': 0.9926758, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'I'}, {'word': 'hope', 'start': 7.8427296, 'end': 8.001973, 'confidence': 0.99853516, 'speaker': 0, 'speaker_confidence': 0.78456384, 'punctuated_word': 'hope'}, {'word': 'it', 'start': 8.001973, 'end': 8.161216, 'confidence': 0.98535156, 'speaker': 0, 'speaker_confidence': 0.7875708, 'punctuated_word': 'it'}, {'word': 'is', 'start': 8.161216, 'end': 8.320459, 'confidence': 0.9848633, 'speaker': 0, 'speaker_confidence': 0.7875708, 'punctuated_word': 'is,'}, {'word': "it's", 'start': 8.798189, 'end': 9.116675, 'confidence': 0.9604492, 'speak ...

# %%
transcript_data
# Out:
# {'metadata': {'transaction_key': 'deprecated',
#   'request_id': '574c48ae-21a6-420a-ba08-f15eafa42c4f',
#   'sha256': 'a689ffaf45498ee3df5d029ddf7ea6fe52d3322f8706bda3927357bca8202253',
#   'created': '2025-01-06T02:45:51.212Z',
#   'duration': 52.2,
#   'channels': 1,
#   'models': ['1ed36bac-f71c-4f3f-a31f-02fd6525c489'],
#   'model_info': {'1ed36bac-f71c-4f3f-a31f-02fd6525c489': {'name': 'general',
#     'version': '2024-01-26.8851',
#     'arch': 'base'}}},
#  'results': {'channels': [{'alternatives': [{'transcript': "Y. Sag, Har, this is just to test to see if the bot is working. And I hope it is, it's recording some audio. I don't know. It's gonna work the way I want to work. But fuck man. Sometimes you just can't do anything. But I wanna make sure the audio filed is, yeah. Is good. Right. But you know, it should get the meeting soon.",
#       'confidence': 0.9404297,
#       'words': [{'word': 'y',
#         'start': 2.8265674,
#         'end': 3.0654323,
#         'confidence': 0.32958984,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'Y.'},
#        {'word': 'sag',
#         'start': 3.543162,
#         'end': 3.782027,
#         'confidence': 0.47973633,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'Sag,'},
#        {'word': 'har',
#         'start': 4.0208917,
#         'end': 4.2597566,
#         'confidence': 0.43945312,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'Har,'},
#        {'word': 'this',
#         'start': 4.817108,
#         'end': 4.8967295,
#         'confidence': 0.9873047,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'this'},
#        {'word': 'is',
#         'start': 4.8967295,
#         'end': 5.055973,
#         'confidence': 0.97558594,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'is'},
#        {'word': 'just',
#         'start': 5.055973,
#         'end': 5.215216,
#         'confidence': 0.9770508,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'just'},
#        {'word': 'to',
#         'start': 5.215216,
#         'end': 5.454081,
#         'confidence': 0.50683594,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'to'},
#        {'word': 'test',
#         'start': 5.454081,
#         'end': 5.613324,
#         'confidence': 0.94433594,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'test'},
#        {'word': 'to',
#         'start': 5.613324,
#         'end': 5.692946,
#         'confidence': 0.9746094,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'to'},
#        {'word': 'see',
#         'start': 5.692946,
#         'end': 5.852189,
#         'confidence': 0.9848633,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'see'},
#        {'word': 'if',
#         'start': 5.852189,
#         'end': 6.011432,
#         'confidence': 0.9765625,
#         'speaker': 0,
#         'speaker_confidence': 0.5785767,
#         'punctuated_word': 'if'},
#        {'word': 'the',
#         'start': 6.011432,
#         'end': 6.091054,
#         'confidence': 0.94140625,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'the'},
#        {'word': 'bot',
#         'start': 6.091054,
#         'end': 6.250297,
#         'confidence': 0.35839844,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'bot'},
#        {'word': 'is',
#         'start': 6.250297,
#         'end': 6.4095407,
#         'confidence': 0.8959961,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'is'},
#        {'word': 'working',
#         'start': 6.4095407,
#         'end': 6.8076487,
#         'confidence': 0.9980469,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'working.'},
#        {'word': 'and',
#         'start': 7.4446216,
#         'end': 7.5242434,
#         'confidence': 0.99316406,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'And'},
#        {'word': 'i',
#         'start': 7.6834865,
#         'end': 7.8427296,
#         'confidence': 0.9926758,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'I'},
#        {'word': 'hope',
#         'start': 7.8427296,
#         'end': 8.001973,
#         'confidence': 0.99853516,
#         'speaker': 0,
#         'speaker_confidence': 0.78456384,
#         'punctuated_word': 'hope'},
#        {'word': 'it',
#         'start': 8.001973,
#         'end': 8.161216,
#         'confidence': 0.98535156,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'it'},
#        {'word': 'is',
#         'start': 8.161216,
#         'end': 8.320459,
#         'confidence': 0.9848633,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'is,'},
#        {'word': "it's",
#         'start': 8.798189,
#         'end': 9.116675,
#         'confidence': 0.9604492,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': "it's"},
#        {'word': 'recording',
#         'start': 9.116675,
#         'end': 9.514784,
#         'confidence': 0.99609375,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'recording'},
#        {'word': 'some',
#         'start': 9.514784,
#         'end': 9.753649,
#         'confidence': 0.9980469,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'some'},
#        {'word': 'audio',
#         'start': 9.753649,
#         'end': 10.231379,
#         'confidence': 0.99560547,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'audio.'},
#        {'word': 'i',
#         'start': 10.947973,
#         'end': 11.027595,
#         'confidence': 0.99121094,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'I'},
#        {'word': "don't",
#         'start': 11.027595,
#         'end': 11.266459,
#         'confidence': 0.9941406,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': "don't"},
#        {'word': 'know',
#         'start': 11.266459,
#         'end': 11.425702,
#         'confidence': 0.99658203,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'know.'},
#        {'word': "it's",
#         'start': 11.983054,
#         'end': 12.142297,
#         'confidence': 0.8642578,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': "It's"},
#        {'word': 'gonna',
#         'start': 12.142297,
#         'end': 12.381162,
#         'confidence': 0.74560547,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'gonna'},
#        {'word': 'work',
#         'start': 12.381162,
#         'end': 12.699649,
#         'confidence': 0.97558594,
#         'speaker': 0,
#         'speaker_confidence': 0.7875708,
#         'punctuated_word': 'work'},
#        {'word': 'the',
#         'start': 12.699649,
#         'end': 12.77927,
#         'confidence': 0.9736328,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'the'},
#        {'word': 'way',
#         'start': 12.77927,
#         'end': 12.938514,
#         'confidence': 0.9946289,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'way'},
#        {'word': 'i',
#         'start': 13.097756,
#         'end': 13.177379,
#         'confidence': 0.99316406,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'I'},
#        {'word': 'want',
#         'start': 13.177379,
#         'end': 13.495865,
#         'confidence': 0.93066406,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'want'},
#        {'word': 'to',
#         'start': 13.495865,
#         'end': 13.6551075,
#         'confidence': 0.98339844,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'to'},
#        {'word': 'work',
#         'start': 13.6551075,
#         'end': 13.814351,
#         'confidence': 0.9741211,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'work.'},
#        {'word': 'but',
#         'start': 15.023886,
#         'end': 15.422293,
#         'confidence': 0.9916992,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'But'},
#        {'word': 'fuck',
#         'start': 15.422293,
#         'end': 15.741019,
#         'confidence': 0.9941406,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'fuck'},
#        {'word': 'man',
#         'start': 15.741019,
#         'end': 15.820701,
#         'confidence': 0.96533203,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'man.'},
#        {'word': 'sometimes',
#         'start': 16.537834,
#         'end': 17.015923,
#         'confidence': 0.9921875,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'Sometimes'},
#        {'word': 'you',
#         'start': 17.015923,
#         'end': 17.175287,
#         'confidence': 0.78564453,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'you'},
#        {'word': 'just',
#         'start': 17.175287,
#         'end': 17.414331,
#         'confidence': 0.9926758,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'just'},
#        {'word': "can't",
#         'start': 17.414331,
#         'end': 17.573694,
#         'confidence': 0.97314453,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': "can't"},
#        {'word': 'do',
#         'start': 17.573694,
#         'end': 17.733057,
#         'confidence': 0.99853516,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'do'},
#        {'word': 'anything',
#         'start': 17.733057,
#         'end': 18.051783,
#         'confidence': 0.9868164,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'anything.'},
#        {'word': 'but',
#         'start': 18.529873,
#         'end': 18.609554,
#         'confidence': 0.9873047,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'But'},
#        {'word': 'i',
#         'start': 18.768917,
#         'end': 18.848598,
#         'confidence': 0.95214844,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'I'},
#        {'word': 'wanna',
#         'start': 18.848598,
#         'end': 18.92828,
#         'confidence': 0.9423828,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'wanna'},
#        {'word': 'make',
#         'start': 18.92828,
#         'end': 19.087643,
#         'confidence': 0.9824219,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'make'},
#        {'word': 'sure',
#         'start': 19.087643,
#         'end': 19.247005,
#         'confidence': 0.9995117,
#         'speaker': 0,
#         'speaker_confidence': 0.7610796,
#         'punctuated_word': 'sure'},
#        {'word': 'the',
#         'start': 19.247005,
#         'end': 19.326687,
#         'confidence': 0.9628906,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'the'},
#        {'word': 'audio',
#         'start': 19.326687,
#         'end': 19.645414,
#         'confidence': 1.0,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'audio'},
#        {'word': 'filed',
#         'start': 19.645414,
#         'end': 20.043821,
#         'confidence': 0.50439453,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'filed'},
#        {'word': 'is',
#         'start': 20.043821,
#         'end': 20.123503,
#         'confidence': 0.9916992,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'is,'},
#        {'word': 'yeah',
#         'start': 21.55777,
#         'end': 21.717134,
#         'confidence': 0.77734375,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'yeah.'},
#        {'word': 'is',
#         'start': 22.03586,
#         'end': 22.354586,
#         'confidence': 0.61572266,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'Is'},
#        {'word': 'good',
#         'start': 22.354586,
#         'end': 22.593632,
#         'confidence': 0.9838867,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'good.'},
#        {'word': 'right',
#         'start': 23.151402,
#         'end': 23.390446,
#         'confidence': 0.6435547,
#         'speaker': 0,
#         'speaker_confidence': 0.77514607,
#         'punctuated_word': 'Right.'},
#        {'word': 'but',
#         'start': 28.11,
#         'end': 28.61,
#         'confidence': 0.5288086,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'But'},
#        {'word': 'you',
#         'start': 28.83,
#         'end': 28.99,
#         'confidence': 0.82910156,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'you'},
#        {'word': 'know',
#         'start': 28.99,
#         'end': 29.15,
#         'confidence': 0.8852539,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'know,'},
#        {'word': 'it',
#         'start': 29.310001,
#         'end': 29.550001,
#         'confidence': 0.32495117,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'it'},
#        {'word': 'should',
#         'start': 29.550001,
#         'end': 29.710001,
#         'confidence': 0.9838867,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'should'},
#        {'word': 'get',
#         'start': 29.710001,
#         'end': 29.87,
#         'confidence': 0.72216797,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'get'},
#        {'word': 'the',
#         'start': 29.87,
#         'end': 29.95,
#         'confidence': 0.87646484,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'the'},
#        {'word': 'meeting',
#         'start': 29.95,
#         'end': 30.27,
#         'confidence': 0.9921875,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'meeting'},
#        {'word': 'soon',
#         'start': 30.27,
#         'end': 30.51,
#         'confidence': 0.9995117,
#         'speaker': 0,
#         'speaker_confidence': 0.80031985,
#         'punctuated_word': 'soon.'}],
#       'paragraphs': {'transcript': "\nSpeaker 0: Y. Sag, Har, this is just to test to see if the bot is working. And I hope it is, it's recording some audio. I don't know. It's gonna work the way I want to work.\n\nBut fuck man. Sometimes you just can't do anything. But I wanna make sure the audio filed is, yeah. Is good. Right.\n\nBut you know, it should get the meeting soon.",
#        'paragraphs': [{'sentences': [{'text': 'Y.',
#            'start': 2.8265674,
#            'end': 3.0654323},
#           {'text': 'Sag, Har, this is just to test to see if the bot is working.',
#            'start': 3.543162,
#            'end': 6.8076487},
#           {'text': "And I hope it is, it's recording some audio.",
#            'start': 7.4446216,
#            'end': 10.231379},
#           {'text': "I don't know.", 'start': 10.947973, 'end': 11.425702},
#           {'text': "It's gonna work the way I want to work.",
#            'start': 11.983054,
#            'end': 13.814351}],
#          'speaker': 0,
#          'num_words': 36,
#          'start': 2.8265674,
#          'end': 13.814351},
#         {'sentences': [{'text': 'But fuck man.',
#            'start': 15.023886,
#            'end': 15.820701},
#           {'text': "Sometimes you just can't do anything.",
#            'start': 16.537834,
#            'end': 18.051783},
#           {'text': 'But I wanna make sure the audio filed is, yeah.',
#            'start': 18.529873,
#            'end': 21.717134},
#           {'text': 'Is good.', 'start': 22.03586, 'end': 22.593632},
#           {'text': 'Right.', 'start': 23.151402, 'end': 23.390446}],
#          'speaker': 0,
#          'num_words': 22,
#          'start': 15.023886,
#          'end': 23.390446},
#         {'sentences': [{'text': 'But you know, it should get the meeting soon.',
#            'start': 28.11,
#            'end': 30.51}],
#          'speaker': 0,
#          'num_words': 9,
#          'start': 28.11,
#          'end': 30.51}]}}]}]}}
